# %%
from hypyflow import blocks, PreprocessingPipeline
from scipy.io import loadmat
import numpy as np
import os

os.chdir("/home/arturo.samayor/Practicas/hyperspectralpreprocessor-main")
number = 142
cube_path = f"/home/arturo.samayor/Practicas/HS-Images/Snapshot/ID_142_CN_2_Ximea Snapshot/SNAPimagesID000142C02_cropped_Pre-processed.mat"
cube = loadmat(cube_path)["CI_cube"]
# Out:
#                      _____                                                                    _____
#                     ( ___ )------------------------------------------------------------------( ___ )
#                      |   |                                                                    |   |
#                      |   |  ██░ ██▓██   ██▓ ██▓███ ▓██   ██▓  █████▒██▓     ▒█████   █     █░ |   |
#                      |   | ▓██░ ██▒▒██  ██▒▓██░  ██▒▒██  ██▒▓██   ▒▓██▒    ▒██▒  ██▒▓█░ █ ░█░ |   |
#                      |   | ▒██▀▀██░ ▒██ ██░▓██░ ██▓▒ ▒██ ██░▒████ ░▒██░    ▒██░  ██▒▒█░ █ ░█  |   |
#                      |   | ░▓█ ░██  ░ ▐██▓░▒██▄█▓▒ ▒ ░ ▐██▓░░▓█▒  ░▒██░    ▒██   ██░░█░ █ ░█  |   |
#                      |   | ░▓█▒░██▓ ░ ██▒▓░▒██▒ ░  ░ ░ ██▒▓░░▒█░   ░██████▒░ ████▓▒░░░██▒██▓  |   |
#                      |   |  ▒ ░░▒░▒  ██▒▒▒ ▒▓▒░ ░  ░  ██▒▒▒  ▒ ░   ░ ▒░▓  ░░ ▒░▒░▒░ ░ ▓░▒ ▒   |   |
# ...

# %%
cube.shape
# Out:
# (200, 231, 25)

# %%
'''# First let's visualize the information!
from hypyflow import HyperspectralViewer, constants

wavelenghts=constants.HEADWALL_VNIR_WAVELENGHTS
# Create and run the viewer
viewer = HyperspectralViewer(cube, wavelenghts)
viewer.run()'''
# Out:
# "# First let's visualize the information!\nfrom hypyflow import HyperspectralViewer, constants\n\nwavelenghts=constants.HEADWALL_VNIR_WAVELENGHTS\n# Create and run the viewer\nviewer = HyperspectralViewer(cube, wavelenghts)\nviewer.run()"

# %%
'''import cv2
import matplotlib.pyplot as plt
ab = cube[:, :, 0:1]

# muestro una imagen de la matriz de datos
plt.imshow(ab)
plt.show()'''


'''img = cv2.imread('/home/arturo.samayor/Practicas/hyperspectralpreprocessor-main/examples/image-1.png')  # Reemplaza 'imagen.jpg' con una imagen que tengas
cv2.imshow('Imagen', img)
cv2.waitKey(0)
cv2.destroyAllWindows()'''


'''plt.figure(figsize=(10, 4))
plt.subplot(121)
plt.imshow(cube, cmap="viridis")'''
# Out:
# 'plt.figure(figsize=(10, 4))\nplt.subplot(121)\nplt.imshow(cube, cmap="viridis")'

# %%
'''from hypyflow import distance_metrics
import matplotlib.pyplot as plt

example_signature = cube[0,0,:]
SAM_map, SAM_mask = distance_metrics.SAM(cube,example_signature, 0.1)
SID_map, SID_mask = distance_metrics.SID(cube,example_signature, 0.1)
SID_SIN_SAM_map, SID_SIN_SAM_mask=distance_metrics.SID_SIN_SAM(cube, example_signature,0.1)
SID_TAN_SAM_map, SID_TAN_SAM_mask=distance_metrics.SID_TAN_SAM(cube, example_signature,0.1)
JM_map, JM_mask=distance_metrics.JM_BC(cube, example_signature,0.1)



# Create a figure with 10 subplots, 5 for each column
fig, axs = plt.subplots(2, 5, figsize=(15, 8))
axs= axs.flatten()
axs[0].imshow(SAM_map)
axs[0].set_title("SAM")
axs[1].imshow(SAM_mask)
axs[1].set_title("SAM Mask")
axs[2].imshow(SID_map)
axs[2].set_title("SID")
axs[3].imshow(SID_mask)
axs[3].set_title("SID Mask")
axs[4].imshow(SID_SIN_SAM_map)
axs[4].set_title("SID SIN SAM")
axs[5].imshow(SID_SIN_SAM_mask)
axs[5].set_title("SID SIN SAM Mask")
axs[6].imshow(SID_TAN_SAM_map)
axs[6].set_title("SID TAN SAM")
axs[7].imshow(SID_TAN_SAM_mask) 
axs[7].set_title("SID TAN SAM Mask")
axs[8].imshow(JM_map)
axs[8].set_title("JM")
axs[9].imshow(JM_mask)
axs[9].set_title("JM Mask")
plt.show()'''
# Out:
# 'from hypyflow import distance_metrics\nimport matplotlib.pyplot as plt\n\nexample_signature = cube[0,0,:]\nSAM_map, SAM_mask = distance_metrics.SAM(cube,example_signature, 0.1)\nSID_map, SID_mask = distance_metrics.SID(cube,example_signature, 0.1)\nSID_SIN_SAM_map, SID_SIN_SAM_mask=distance_metrics.SID_SIN_SAM(cube, example_signature,0.1)\nSID_TAN_SAM_map, SID_TAN_SAM_mask=distance_metrics.SID_TAN_SAM(cube, example_signature,0.1)\nJM_map, JM_mask=distance_metrics.JM_BC(cube, example_signature,0.1)\n\n\n\n# Create a figure with 10 subplots, 5 for each column\nfig, axs = plt.subplots(2, 5, figsize=(15, 8))\naxs= axs.flatten()\naxs[0].imshow(SAM_map)\naxs[0].set_title("SAM")\naxs[1].imshow(SAM_mask)\naxs[1].set_title("SAM Mask")\naxs[2].imshow(SID_map)\naxs[2].set_title("SID")\naxs[3].imshow(SID_mask)\naxs[3].set_title("SID Mask")\naxs[4].imshow(SID_SIN_SAM_map)\naxs[4].set_title("SID SIN SAM")\naxs[5].imshow(SID_SIN_SAM_mask)\naxs[5].set_title("SID SIN SAM Mask")\naxs[6].imshow(SID_TA
# ...

# %%
# hago que la variable cube, en lugar de la tercera dimension tener 369 dimensiones, tenga desde la 100 hasta la 369
#cube = cube[:,:,100:369]
preprocesschain = [
    blocks.MaskNegativeValues(),
    blocks.MaskZeroValues(),
    blocks.MaskSaturatedValues(99.999), #
    blocks.ProcessNormalize(type="MinMax"),#
    blocks.ProcessDenoise(),
    blocks.MaskRxAnomalyDetection(0.3), #
    #blocks.MaskTargetSignature(interactive=True,select_area=True,method="SID"), #TODO: hacer que la barra selectora sea logarítmica, para que cuando me acerque a 0.1 no sea tan dificil seleccionar
    blocks.MaskTargetSignature(interactive=True,select_area=True,method="SAM"),
    blocks.ProcessSmoothSpectral(),
    blocks.ProcessSmoothSpatial(),
    blocks.MaskZeroValues()
]

try:
    full_mask = np.load(f"/home/arturo.samayor/Practicas/data/masks_{number}.npy")
    masks = None
except:
    full_mask = None
    masks = None
pre = PreprocessingPipeline(cube)
filtered_data, full_mask, masks = pre(preprocesschain, verbose=False, plot_masks=True, mask=full_mask) # donde full_mask es la mascara final

np.save(f"/home/arturo.samayor/Practicas/data/masks_{number}.npy", full_mask)
# Out:
#  - Using previous mask, skipping masking blocks

# %% [markdown]
# ## Máscara antes de transformación a Absorbancia

# %%
import numpy as np
from scipy.optimize import least_squares
from joblib import Parallel, delayed
import matplotlib.pyplot as plt
from tqdm.auto import tqdm,trange

def from_reflectance_to_absorbance(data_reflectance):
    epsilon = 1e-10  # Un valor pequeño para evitar el logaritmo de cero
    reflectance = np.clip(data_reflectance, epsilon, np.max(data_reflectance))  # Recorta los valores entre epsilon y 1
    absorbance = -np.log10(reflectance)
    return absorbance

# método de aplicación de la máscara
def apply_mask(data, mask):
    masked_data = np.zeros_like(data)
    for i in range(data.shape[2]):
        masked_data[:, :, i] = np.where(mask, data[:, :, i], 0)
    return masked_data


hb_sign = np.loadtxt("../hb_sign_reduced.txt")[:, 1]
hbO2_sign = np.loadtxt("../hbo2_sign_reduced.txt")[:, 1]

# normalizo las señales
hb_sign = (hb_sign - np.min(hb_sign)) / (np.max(hb_sign) - np.min(hb_sign))
hbO2_sign = (hbO2_sign - np.min(hbO2_sign)) / (np.max(hbO2_sign) - np.min(hbO2_sign))


filtered_data_absorbance = from_reflectance_to_absorbance(cube)


# normalizo masked_cube
masked_cube = (filtered_data_absorbance - np.min(filtered_data_absorbance)) / (np.max(filtered_data_absorbance) - np.min(filtered_data_absorbance))
masked_cube = apply_mask(masked_cube, full_mask)
#masked_cube = masked_cube[:,:,62:369]


new_masked_cube = masked_cube#[:,:,::3]
hb_sign_new = hb_sign#[::3]
hbO2_sign_new = hbO2_sign#[::3]

# Generar una señal aleatoria para representar el fondo o el ruido
np.random.seed(0)  # Fija la semilla para reproducibilidad
background_sign = np.random.rand(len(hb_sign_new))

# Obtenemos la absorbancia de los datos filtrados



print(new_masked_cube.shape)
plt.imshow(new_masked_cube[:, :, 0], cmap="viridis")

#depth = 3000.0
#filtered_data_absorbance = filtered_data_absorbance * depth

print(np.max(new_masked_cube), np.min(new_masked_cube))

height, width, bands = new_masked_cube.shape
print("Formas - hb_sign:", hbO2_sign_new.shape, "hbO2_sign:", hb_sign_new.shape, "filtered_data:", new_masked_cube.shape)

# Inicialización de las matrices de abundancias
ab_hb = np.zeros((height, width))
ab_hbo2 = np.zeros((height, width))
ab_background = np.zeros((height, width))

# Función para calcular los residuos
def residuals(x, pixel, hb_sign, hbo2_sign, background_sign):
    #depth = 3000.0
    ab_hb, ab_hbo2, ab_bg  = x # x es un vector con dos elementos: ab_hb y ab_hbo2
    model = (ab_hb * hb_sign + ab_hbo2 * hbo2_sign + ab_bg *background_sign)#*depth  # Modelo lineal de absorbancia
    return RMSE(pixel,model)
    return pixel - model  # Residuos: diferencia entre lo observado y lo modelado


def RMSE(y1,y2):
    return np.sqrt(np.mean((y1-y2)**2))
# Aplicar least_squares
def process_pixel(i, j):
    pixel = new_masked_cube[i, j, :]  # Datos de absorbancia del píxel
    
    # si el píxel es 0 por la máscara, no calcula nada
    if pixel.sum() == 0:
        #print("este pixel es 0")
        return i, j, [0, 0, 0]
        
    '''if np.all(pixel == 0):
        return i, j, [0, 0]'''
    
    
    
    initial_guess = [0.1, 0.1, 0.01]  # Un punto de partida para ab_hb y ab_hbo2
    
    # Ejecutar least_squares
    result = least_squares(residuals, initial_guess, args=(pixel, hb_sign_new, hbO2_sign_new, background_sign), bounds=([0, 0, 0], [1, 1, 1]))
    # los valores negativos los pongo a 0
    #result.x[result.x < 0] = 0
    return i,j,result.x

results = Parallel(n_jobs=40)(delayed(process_pixel)(i, j) for i in trange(height) for j in range(width))

for i, j, abundances in results:
    #print(abundances)
    ab_hb[i, j], ab_hbo2[i, j], ab_background[i, j] = abundances
        
# Mostrar los valores mínimos y máximos de cada matriz de abundancias
print("Hb min/max:", np.min(ab_hb), np.max(ab_hb))
print("HbO2 min/max:", np.min(ab_hbo2), np.max(ab_hbo2))
#print("Background min/max:", np.min(ab_background), np.max(ab_background))
# Out:
# (200, 231, 25)
# 0.33406153494747454 0.0
# Formas - hb_sign: (25,) hbO2_sign: (25,) filtered_data: (200, 231, 25)
#   0%|          | 0/200 [00:00<?, ?it/s]
# Hb min/max: 0.0 0.3287619213879246
# HbO2 min/max: 0.0 0.1977113549690937

# %% [markdown]
# ## Mostrar niveles de Hb y HbO2

# %%
# Visualizamos las abundancias
# muestro los máximos y mínimos de cada matriz
print("Abundancia Hb: min:", ab_hb.min(), "max:", ab_hb.max())
print("Abundancia HbO2: min:", ab_hbo2.min(), "max:", ab_hbo2.max())



if (ab_hb.max() > ab_hbo2.max()):
    abmax = ab_hb.max()
else: abmax = ab_hbo2.max()
    

plt.figure(figsize=(10, 4))
plt.subplot(121)
plt.imshow(ab_hb, cmap="viridis", vmin=0)
plt.title("Abundancia Hb")
plt.subplot(122)
plt.imshow(ab_hbo2, cmap="viridis", vmin=0)
plt.title("Abundancia HbO2")
plt.show()

# muestro la imagen de ab_background
plt.imshow(ab_background, cmap="viridis", vmin=0)
plt.title("Abundancia Background")
plt.show()

print(new_masked_cube.max(), new_masked_cube.min())
print(masked_cube.max(), masked_cube.min())
# Out:
# Abundancia Hb: min: 0.0 max: 0.3287619213879246
# Abundancia HbO2: min: 0.0 max: 0.1977113549690937
# 0.33406153494747454 0.0
# 0.33406153494747454 0.0

# %% [markdown]
# ## Mostrar niveles de StO2

# %%
# sto2 = (hbo2)/(hb + hbo2) * 100
sto2 = (ab_hbo2) / (ab_hb + ab_hbo2)

# mostramos los máximos y mínimos de la matriz de sto2
print("STO2: min:", sto2.min(), "max:", sto2.max())

# Visualizamos el STO2
plt.figure(figsize=(5, 5))
plt.imshow(sto2, cmap="viridis", vmin=0)
plt.title("STO2")
plt.show()
# Out:
# STO2: min: nan max: nan
# /tmp/ipykernel_2032942/1761579020.py:2: RuntimeWarning: invalid value encountered in divide
#   sto2 = (ab_hbo2) / (ab_hb + ab_hbo2)
